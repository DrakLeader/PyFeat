# %%
import os
import time
import numpy as np
from numpy import mean
from numpy import std
from numpy import absolute
import pandas as pd
from joblib import dump,load

from sklearn.model_selection import train_test_split
from sklearn.model_selection import LeaveOneOut, cross_validate
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler,RobustScaler, Normalizer
from sklearn.pipeline import make_pipeline, make_union
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor, ExtraTreesRegressor
from sklearn.linear_model import ElasticNetCV, SGDRegressor, RidgeCV, LassoLarsCV
from sklearn.svm import LinearSVR
from tpot.builtins import StackingEstimator
from xgboost import XGBRegressor
from sklearn.metrics import explained_variance_score, max_error, mean_absolute_error, mean_squared_error
from sklearn.metrics import mean_squared_log_error, median_absolute_error, r2_score, accuracy_score

# %%
os.chdir(r'D:\24-project-ChenXiao-2021211022\实验2\实验2\数据')
os.getcwd()
# Out:
# 'D:\\24-project-ChenXiao-2021211022\\实验2\\实验2\\数据'

# %%
data1=pd.read_csv("./training_ALL_NOECYEAST8.csv",sep='\t')
data2=pd.read_csv("./training_MIN_NOECYEAST8.csv",sep='\t')
data3=pd.read_csv("./training_YPD_NOECYEAST8.csv",sep='\t')

# %%
data1.shape,data2.shape,data3.shape,
# Out:
# ((4445, 94), (4262, 94), (4193, 94))

# %%
objnames=[data1,data2,data3]
dataset=[]
for dt in objnames:
    dataset.append((dt.iloc[:,3:].values,np.log1p(dt['Median molecules per cell'].values).reshape((-1,1))))
dataset
# Out:
# [(array([[20.        ,  0.22787714,  0.5138    , ..., 51.85628743,
#           47.66467066,  9.93865031],
#          [20.        ,  0.24213129,  0.5508    , ..., 46.5497076 ,
#           53.33333333, 13.31719128],
#          [20.        ,  0.19979066,  0.614     , ..., 45.19230769,
#           52.16346154,  3.7593985 ],
#          ...,
#          [42.67543199,  0.23430414,  0.4095    , ..., 48.89705882,
#           51.83823529, 30.19230769],
#          [41.48925514,  0.22225243,  0.4506    , ..., 42.37288136,
#           49.49152542, 34.26573427],
#          [37.62649346,  0.28609985,  0.3619    , ..., 45.69215876,
#           53.43659245, 47.94383149]]),
#   array([[5.86962247],
#          [5.60580207],
#          [6.93731408],
#          ...,
#          [7.11889492],
#          [7.05427321],
#          [5.91862048]])),
#  (array([[20.        ,  0.22787714,  0.5138    , ..., 51.85628743,
#           47.66467066,  9.93865031],
#          [20.        ,  0.24213129,  0.5508    , ..., 46.5497076 ,
#           53.33333333, 13.31719128],
#          [20.        ,  0.22744027,  0.5229    , ..., 52.6032316 ,
#           47.03770197,  6.20300752],
#          ...,
#          [42.67543199,  0.23430414,  0.4095    , ..., 48.89705882,
#           51.83823529, 30.19230769],
#          [41.48925514,  0.22225243,  0.4506    , ..., 42.37288136,
#           49.49152542, 34.26573427],
#          [37.62649346,  0.28609985,  0.3619    , ..., 45.69215876,
#           53.43659245, 47.94383149]]),
#   array([[5.86962247],
#          [6.05943507],
#          [5.28826703],
#          ...,
#          [7.11889492],
#          [7.05427321],
#          [6.45492788]])),
#  (array([[20.        ,  0.22787714,  0.5138    , ..., 51.85628743,
#           47.66467066,  9.93865031],
#          [20.        ,  0.24213129,  0.5508    , ..., 46.5497076 ,
#           53.33333333, 13.31719128],
#          [20.        ,  0.19979066,  0.614     , ..., 45.19230769,
#           52.16346154,  3.7593985 ],
#          ...,
#          [45.07336436,  0.2184083 ,  0.4557    , ..., 42.88747346,
#           53.92781316, 34.        ],
#          [42.67543199,  0.23430414,  0.4095    , ..., 48.89705882,
#           51.83823529, 30.19230769],
#          [37.62649346,  0.28609985,  0.3619    , ..., 45.69215876,
#           53.43659245, 47.94383149]]),
#   array([[5.62068321],
#          [1.86026145],
#          [6.93731408],
#          ...,
#          [2.13780645],
#          [6.90044829],
#          [4.68184202]]))]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
res=[]
label_0=[]
for X,_ in dataset:
    model=KMeans(n_clusters=2)
    model.fit(X)
    pre_y=model.labels_#获取训练后的 KMeans 模型对当前样本的聚类结果，即每个样本所属的簇标签。
    s=silhouette_score(X,pre_y,sample_size=len(X),metric='euclidean')
    res.append(s)
print(res)
# Out:
# [0.6221307474301416, 0.622473469132409, 0.6214320224384887]

# %% [markdown]
# 作业1

# %%
data3
# Out:
#      Protein(Ensembl) Standard Name  Median molecules per cell       iCUB  \
# 0               Q0050           AI1                 275.077938  20.000000
# 1               Q0055           AI2                   5.425417  20.000000
# 2               Q0060           AI3                1029.000000  20.000000
# 3               Q0065           AI4                  58.683181  20.000000
# 4               Q0140          VAR1                3973.295137  44.040868
# ...               ...           ...                        ...        ...
# 4188          YPR189W          SKI3                5379.370745  34.092577
# 4189          YPR190C         RPC82                4996.159632  40.638423
# 4190          YPR196W       YPR196W                   7.480814  45.073364
# 4191          YPR198W          SGE1                 991.719640  42.675432
# 4192          YPR204W       YPR204W                 106.968771  37.626493
#
#            tAI     T3s     C3s     A3s     G3s  CAI_CODONW  ...        %C3  \
# 0     0.227877  0.5138  0.0639  0.6199  0.0731       0.123  ...   5.269461
# 1     0.242131  0.5508  0.0932  0.5525  0.0861       0.156  ...   7.719298
# 2     0.199791  0.6140  0.0205  0.6282  0.0329       0.122  ...   1.682692
# 3     0.227440  0.5229  0.0479  0.6540  0.0328       0.121  ...   3.949731
# 4     0.143927  0.7249  0.0258  0.5714  0.0486       0.089  ...   2.255639
# ...        ...     ...     ...     ...     ...         ...  ...        ...
# 4188  0.267476  0.4672  0.1896  0.4340  0.2307       0.148  ...  14.305652
# 4189  0.305205  0.3587  0.2064  0.4434  0.2515       0.149  ...  15.725191
# 4190  0.218408  0.4557  0.2057  0.3836  0.2578       0.120  ...  16.772824
# 4191  0.234304  0.4095  0.1983  0.4314  0.1884       0.096  ...  16.911765
# 4192  0.286100  0.3619  0.3040  0.2779  0.3034       0.109  ...  24.394966
#
#             %T3        %G3     %G3+C3     %G3+A3     %G3+T3     %A3+T3  \
# 0     42.395210   5.748503  11.017964  52.335329  48.143713  88.982036
# 1     45.614035   7.836257  15.555556  46.666667  53.450292  84.444444
# 2     50.480769   4.326923   6.009615  47.836538  54.807692  93.990385
# 3     43.087971   4.308797   8.258528  52.962298  47.396768  91.741472
# 4     63.408521   2.255639   4.511278  34.335840  65.664160  95.488722
# ...         ...        ...        ...        ...        ...        ...
# 4188  35.240754  18.283322  32.588974  50.453594  53.524075  67.411026
# 4189  27.328244  21.526718  37.251908  56.946565  48.854962  62.748092
# 4190  37.154989  19.957537  36.730361  46.072187  57.112527  63.269639
# 4191  34.926471  16.176471  33.088235  48.161765  51.102941  66.911765
# 4192  29.041626  25.266215  49.661181  46.563408  54.307841  50.338819
#
#          %A3+C3     %C3+T3   %G3s+C3s
# 0     51.856287  47.664671   9.938650
# 1     46.549708  53.333333  13.317191
# 2     45.192308  52.163462   3.759398
# 3     52.603232  47.037702   6.203008
# 4     34.335840  65.664160   4.071247
# ...         ...        ...        ...
# 4188  46.475925  49.546406  30.475504
# 4189  51.145038  43.053435  35.433071
# 4190  42.887473  53.927813  34.000000
# 4191  48.897059  51.838235  30.192308
# 4192  45.692159  53.436592  47.943831
#
# [4193 rows x 94 columns]

# %%
pre_y_3=pre_y
import pandas as pd
data3['KM'] = pre_y_3
data3
name = data3.iloc[:, 0]
KM = data3['KM']
df1 = pd.DataFrame({'name': name, 'KM': KM})
print(df1)
# Out:
#          name  KM
# 0       Q0050   1
# 1       Q0055   1
# 2       Q0060   0
# 3       Q0065   0
# 4       Q0140   0
# ...       ...  ..
# 4188  YPR189W   1
# 4189  YPR190C   0
# 4190  YPR196W   0
# 4191  YPR198W   0
# 4192  YPR204W   1
#
# [4193 rows x 2 columns]

# %%
name = df1['name']
KM= df1['KM']
name0 = name[KM == 0]  # 第二列为 0 的数据
name1 = name[KM == 1]  # 第二列为 1 的数据
print(name0)
print(name1)
# Out:
# 2         Q0060
# 3         Q0065
# 4         Q0140
# 7       YAL003W
# 8       YAL005C
#          ...
# 4186    YPR187W
# 4187    YPR188C
# 4189    YPR190C
# 4190    YPR196W
# 4191    YPR198W
# Name: name, Length: 3312, dtype: object
# 0         Q0050
# 1         Q0055
# 5       YAL001C
# 6       YAL002W
# 18      YAL017W
#          ...
# 4167    YPR164W
# 4182    YPR181C
# 4184    YPR185W
# 4188    YPR189W
# 4192    YPR204W
# Name: name, Length: 881, dtype: object

# %%
df2 = data3.iloc[:, [0, 2]]
df2_sorted = df2.sort_values(by=df2.columns[1], ascending=False)
print(df2_sorted)
# Out:
#      Protein(Ensembl)  Median molecules per cell
# 222           YBR118W              611192.841299
# 4109          YPR080W              291691.101487
# 8             YAL005C              262450.500000
# 2485          YLL024C              185858.422435
# 2674          YLR249W              172751.212100
# ...               ...                        ...
# 1612          YGR249W                   4.013483
# 2039          YJL093C                   3.804228
# 3069          YMR191W                   3.359783
# 145           YBL106C                   2.945467
# 982           YDR501W                   2.197335
#
# [4193 rows x 2 columns]

# %%
top_10_percent = int(len(df2_sorted) * 0.1)
top_10_data = df2_sorted.head(top_10_percent)
bottom_10_data = df2_sorted.tail(top_10_percent)
print("前百分之10数据:")
print(top_10_data)
print("\n后百分之10数据:")
print(bottom_10_data)
# Out:
# 前百分之10数据:
#      Protein(Ensembl)  Median molecules per cell
# 222           YBR118W              611192.841299
# 4109          YPR080W              291691.101487
# 8             YAL005C              262450.500000
# 2485          YLL024C              185858.422435
# 2674          YLR249W              172751.212100
# ...               ...                        ...
# 2858          YML048W               11869.410734
# 3196          YNL044W               11865.591670
# 544           YDL125C               11846.440664
# 104           YBL050W               11753.784790
# 1406          YGL200C               11721.501456
#
# [419 rows x 2 columns]
#
# 后百分之10数据:
#      Protein(Ensembl)  Median molecules per cell
# 1762          YHR124W                 440.834490
# 2389          YKL219W                 440.834490
# 874           YDR350C                 440.834490
# 809           YDR255C                 440.834490
# 157           YBR021W                 439.151265
# ...               ...                        ...
# 1612          YGR249W                   4.013483
# 2039          YJL093C                   3.804228
# 3069          YMR191W                   3.359783
# 145           YBL106C                   2.945467
# 982           YDR501W                   2.197335
#
# [419 rows x 2 columns]

# %%
from matplotlib import pyplot as plt
from matplotlib_venn import venn2
set1 = set(top_10_data.iloc[:,0])
print('****************************')
print(set1)
set2 = set(name0)
print('****************************')
print(name1)
venn2([set1, set2], ('Set1', 'Set2'))
plt.show()
# Out:
# 222     YBR118W
# 4109    YPR080W
# 8       YAL005C
# 2485    YLL024C
# 2674    YLR249W
#          ...
# 2858    YML048W
# 3196    YNL044W
# 544     YDL125C
# 104     YBL050W
# 1406    YGL200C
# Name: Protein(Ensembl), Length: 419, dtype: object
# ****************************
# {'YDR385W', 'YGL030W', 'YDR099W', 'YNL098C', 'YER048C', 'YGR034W', 'YML092C', 'YDR500C', 'YOR361C', 'YPL090C', 'YKL006W', 'YLR293C', 'YMR143W', 'YML028W', 'YLR029C', 'YPR041W', 'YJR077C', 'YMR146C', 'YBL072C', 'YIL133C', 'YGL206C', 'YNL015W', 'YOR237W', 'YCL043C', 'YKL096W-A', 'YBR067C', 'YOL109W', 'YLR185W', 'YKR001C', 'YOR214C', 'YLR150W', 'YNL096C', 'YER102W', 'YDR025W', 'YDR471W', 'YGL106W', 'YPL143W', 'YGR214W', 'YDL075W', 'YFR004W', 'YPL218W', 'YNR035C', 'YLR406C', 'YER094C', 'YGL103W', 'YNL044W', 'YOR254C', 'YJL177W', 'YNL302C', 'YKL145W', 'YJL191W', 'YLR347C', 'YLR378C', 'YBL041W', 'YPL220W', 'YMR142C', 'YDR168W', 'YMR290C', 'YBR128C', 'YDR233C', 'YBL087C', 'YPL154C', 'YMR235C', 'YDL137W', 'YBL047C', 'YPL198W', 'YCR009C', 'YMR241W', 'YBR078W', 'YIL051C', 'YPR110C', 'YAL005C', 'YER117W', 'YOR341W', 'YKR059W', 'YKR057W', 'YOR198C', 'YER036C', 'YLR110C', 'YML078W', 'YKL009W', 'YBR106W', 'YER012W', 'YDL145C', 'YLR102C', 'YOR182C', 'YNL121C', 'YKL156W', 'YPL249C-A', 'YPL048W', 'YMR314W', 'YER057C', 'YGL207W', 'YHL001W', 'YGR159C', 'YER131W', 'YML048W', 'YDL140C', 'YJR145C', 'YFR009W', 'YBR031W', 'YDR374W-A', 'YNL135C', 'YLR216C', 'YLR259C', 'YER025W', 'YOR151C', 'YJL190C', 'YDR101C', 'YNR021W', 'YMR116C', 'YFR052W', 'YDR129C', 'YER009W', 'YOR027W', 'YBL003C', 'YJL111W', 'YHL015W', 'YPL004C', 'YNL162W', 'YLR344W', 'YPL192C', 'YIL075C', 'YLR167W', 'YGR211W', 'YMR038C', 'YBR191W', 'YDR212W', 'YLR287C-A', 'YHR203C', 'YJR070C', 'YOR133W', 'YDL081C', 'YGL031C', 'YNL064C', 'YEL026W', 'YOL154W', 'YOR310C', 'YNL209W', 'YIL023C', 'YOL127W', 'YPL037C', 'YMR260C', 'YPR163C', 'YDR461W', 'YAL016W', 'YDL208W', 'YKL056C', 'YDL124W', 'YBR048W', 'YMR251W-A', 'YDL130W', 'YKL117W', 'YER056C-A', 'YBR085C-A', 'YMR012W', 'YDR346C', 'YBR010W', 'YKL210W', 'YFL038C', 'YKL180W', 'YDL229W', 'YGR037C', 'YDR155C', 'YLR448W', 'YJL008C', 'YDR091C', 'YER177W', 'YGR285C', 'YDL097C', 'YPL079W', 'YDL086W', 'YER120W', 'YNL287W', 'YBR189W', 'YDL184C', 'YML024W', 'YER110C', 'YJL014W', 'YJR065C', 'YKL054C', 'YDR447C', 'YML012W', 'YER072W', 'YGL011C', 'YER146W', 'YBL027W', 'YLR175W', 'YBR143C', 'YNL007C', 'YDR382W', 'YDR033W', 'YOR204W', 'YBR118W', 'YBR084C-A', 'YPL237W', 'YDL125C', 'YGL255W', 'YPL106C', 'YMR230W', 'YIL018W', 'YDL083C', 'YOL139C', 'YOR234C', 'YGR054W', 'YNL067W', 'YGR118W', 'YLL050C', 'YBL092W', 'YFL037W', 'YLR197W', 'YDR032C', 'YGR086C', 'YHL033C', 'YHR107C', 'YJL117W', 'YOR096W', 'YJL138C', 'YFL014W', 'YNL208W', 'YDL195W', 'YHR021C', 'YOL040C', 'YKR094C', 'YML026C', 'YCL037C', 'YEL054C', 'YFR032C-A', 'YER136W', 'YCL042W', 'YLR048W', 'YBR072W', 'YLL009C', 'YGL105W', 'YBR009C', 'YMR307W', 'YDR225W', 'YPL240C', 'YER133W', 'YDR188W', 'YHR089C', 'YDL147W', 'YDR525W-A', 'YMR315W', 'YHR072W-A', 'YPR102C', 'YOL121C', 'YGL135W', 'YNL231C', 'YLR301W', 'YOR230W', 'YMR186W', 'YOR167C', 'YGL200C', 'YDR343C', 'YDL084W', 'YML073C', 'YDR002W', 'YJL012C', 'YDR224C', 'YJR045C', 'YGR253C', 'YDL191W', 'YLR075W', 'YOL039W', 'YLR249W', 'YER007C-A', 'YGR148C', 'YEL034W', 'YPL131W', 'YDR064W', 'YMR229C', 'YLR061W', 'YOR063W', 'YGL225W', 'YDR450W', 'YJR064W', 'YHR141C', 'YBR109C', 'YAR050W', 'YDR238C', 'YDR510W', 'YBR025C', 'YGL147C', 'YKR048C', 'YML058W', 'YOR210W', 'YOR369C', 'YNL010W', 'YBL001C', 'YPR010C', 'YDL082W', 'YKL081W', 'YOR187W', 'YNL178W', 'YNL030W', 'YGL076C', 'YJR123W', 'YDL061C', 'YOR117W', 'YHL034C', 'YMR092C', 'YIL165C', 'YJR094W-A', 'YFL039C', 'YNL301C', 'YFR050C', 'YPR016C', 'YFL005W', 'YDR429C', 'YPL260W', 'YPR043W', 'YLL026W', 'YHR179W', 'YNL031C', 'YDL160C', 'YOR020C', 'YJL159W', 'YMR309C', 'YPL226W', 'YGL195W', 'YLR208W', 'YBL002W', 'YOR007C', 'YNL069C', 'YDR214W', 'YMR242C', 'YIL052C', 'YNL055C', 'YLR314C', 'YBL050W', 'YBL030C', 'YLR333C', 'YLR367W', 'YOR298C-A', 'YFR031C-A', 'YER074W', 'YDL143W', 'YGR106C', 'YDL007W', 'YGL048C', 'YBR082C', 'YGL173C', 'YGR135W', 'YLR325C', 'YDL014W', 'YMR194W', 'YLR257W', 'YNL244C', 'YOR276W', 'YBR079C', 'YHR064C', 'YGR085C', 'YHR193C', 'YDR432W', 'YOR293W', 'YOR122C', 'YLL045C', 'YGR027C', 'YDL133C-A', 'YDL126 ...
# ****************************
# 0         Q0050
# 1         Q0055
# 5       YAL001C
# 6       YAL002W
# 18      YAL017W
#          ...
# 4167    YPR164W
# 4182    YPR181C
# 4184    YPR185W
# 4188    YPR189W
# 4192    YPR204W
# Name: name, Length: 881, dtype: object

# %%
from scipy.cluster.hierarchy import dendrogram
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
def plot_dendrogram(model,**kwargs):
    counts = np.zeros(model.children_.shape[0])
    n_samples=len(model.labels_)
    for i,merge in enumerate(model.children_):
        current_count=0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count+=1
            else:
                current_count+=counts[child_idx-n_samples]
        counts[i]=current_count
    linkage_matrix=np.column_stack([model.children_,model.distances_,counts]).astype(float)
    dendrogram(linkage_matrix,**kwargs)
X,_=dataset[0]
model =AgglomerativeClustering(distance_threshold=2,n_clusters=None)
model=model.fit(X)
plt.title('Hierarchical Clustering Dendrogram of data1')
plot_dendrogram(model,truncate_mode='level',p=4,labels=data1['Standard Name'].to_list())
plt.xlabel("Node od Tree")
plt.show()

# %%
X,_=dataset[2]
model =AgglomerativeClustering(distance_threshold=2,n_clusters=None)
model=model.fit(X)
plt.title('Hierarchical Clustering Dendrogram of data3')
plot_dendrogram(model,truncate_mode='level',p=4,labels=data3['Standard Name'].to_list())
plt.xlabel("Node of Tree")
plt.show()

model=AgglomerativeClustering(distance_threshold=None,n_clusters=2)
model=model.fit(X)
print(model.fit(X))
# Out:
# AgglomerativeClustering()

# %%
X,_=dataset[1]
model =AgglomerativeClustering(distance_threshold=2,n_clusters=None)
model=model.fit(X)
plt.title('Hierarchical Clustering Dendrogram of data2')
plot_dendrogram(model,truncate_mode='level',p=4,labels=data2['Standard Name'].to_list())
plt.xlabel("Node of Tree")
plt.show()
